# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from wordcloud import WordCloud

# %%
df = pd.read_excel("UNESCOs_Technology_Enabled_Open_School_Project_TeOSS_Learners_Training_Program_Post-Training_Assessment_.xlsx")
df.head()
# Out:
#                     start                     end            1. Name  2. Age  \
# 0 2024-09-17 10:10:42.110 2024-09-17 10:18:55.756        SAMLA MELODY     11
# 1 2024-09-17 08:54:55.748 2024-09-17 10:30:09.788       MENSAH DENNIS      9
# 2 2024-09-17 10:30:10.002 2024-09-17 10:37:43.941  AMEEVOR EMMANUELLA      9
# 3 2024-09-17 10:37:44.060 2024-09-17 10:48:22.056        DOGBEY BLESS      8
# 4 2024-09-17 10:48:22.264 2024-09-17 11:21:45.844        SACKEY BETTY     11
#
#   3. Gender         4. Name of School 5. Grade/Class 6. Region of School  \
# 0    Female  AKATSI NO.1 BASIC SCHOOL      Primary 2               Volta
# 1      Male        AKATSI NO. 1 BASIC      Primary 2               Volta
# 2    Female        AKATSI NO. 1 BASIC      Primary 2               Volta
# 3    Female                       NaN      Primary 2               Volta
# 4    Female        AKATSI NO. 1 BASIC      Primary 2               Volta
#
#   7. How would you rate the overall training experience?  \
# 0                                               Good
# 1                                               Good
# 2                                               Good
# 3                                          Very good
# 4                                          Very good
#
#   8. What aspects of the training did you enjoy most?  ...        _id  \
# 0                                        All aspects   ...  384507902
# 1                                             TYPING   ...  384513668
# 2                                         EVERYTHING   ...  384517331
# 3                                       WHEN WE SANG   ...  384522893
# 4                                         EVERYTHING   ...  384539518
#
#                                   _uuid    _submission_time  \
# 0  0b06f199-2b8c-4a9e-ac5b-6f2e84c2d173 2024-09-17 10:18:57
# 1  ba6b129d-4e76-4318-82c8-a800bba3bc00 2024-09-17 10:30:03
# 2  4fdf981d-5293-4e94-a6e0-6c5703a13070 2024-09-17 10:37:37
# 3  b2df8d95-1dd2-43fe-a159-43fdc3aa4a86 2024-09-17 10:48:15
# 4  67f8f906-be24-419d-942b-23ca02bb2b91 2024-09-17 11:21:39
#
#   _validation_status _notes            _status _submitted_by  \
# 0                NaN    NaN  submitted_via_web           NaN
# 1                NaN    NaN  submitted_via_web           NaN
# 2                NaN    NaN  submitted_via_web           NaN
# 3                NaN    NaN  submitted_via_web           NaN
# 4                NaN    NaN  submitted_via_web           NaN
#
#               __version__ _tags _index
# 0  vRnq38mdhav6ufiNCRBvdB   NaN      1
# 1  vRnq38mdhav6ufiNCRBvdB   NaN      2
# 2  vRnq38mdhav6ufiNCRBvdB   NaN      3
# 3  vRnq38mdhav6ufiNCRBvdB   NaN      4
# 4  vRnq38mdhav6ufiNCRBvdB   NaN      5
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['start', 'end', '1. Name ', '2. Age', '3. Gender', '4. Name of School',
#        '5. Grade/Class', '6. Region of School',
#        '7. How would you rate the overall training experience?',
#        '8. What aspects of the training did you enjoy most?',
#        '9. Were the training objectives clearly communicated?',
#        '10. How engaging did you find the training sessions?',
#        '11. How effective were the trainers in delivering the content?',
#        '12. How would you rate the training materials provided?',
#        '13. What new skills or knowledge did you acquire from the training?',
#        '14. How confident do you feel in using technology for learning after the training?',
#        '15. What challenges did you encounter while using technology during the training?',
#        '16. How do you plan to apply what you learned in your studies?',
#        '17. What topics would you like to see covered in future training sessions?',
#        '18. Do you have any suggestions to improve the training program?',
#        '19. Any additional comments or feedback?', '4. Grade/Class',
#        '5. Region of School',
#        '6. How would you rate the overall training experience?',
#        '7. What aspects of the training did you enjoy most?',
#        '8. Were the training objectives clearly communicated?',
#        '9. How engaging did you find the training sessions?',
#        '10. How effective were the trainers in delivering the content?',
#        '11. How would you rate the training materials provided?',
#        '12. What new skills or knowledge did you acquire from the training?',
#        '13. How confident do you feel in using technology for learning after the training?',
#        '14. What challenges did you encounter while using technology during the training?',
#        '15. How do you plan to apply what you learned in your studies?',
#        '16. What topics would you like to see covered in future training sessions?',
#        '17. Do you have any suggestions to improve the training program?',
#        '18. Any additional comments or feedback?', '_id', '_uuid',
#        '_submission_time', '_validation_status', '_notes', '_status',
#        '_submitted_by', '__version__', '_tags', '_index'],
#       dtype='object')

# %%
df.rename(columns = {"start":"start_time", "end":"end_time", "1. Name":"name", "2. Age":"age", "3. Gender":"gender", "4. Name of School":"name_of_school",
                    "5. Grade/Class":"grade_or_class", "6. Region of School":"region_of_school", "7. How would you rate the overall training experience?":"how_would_you_rate_the_overall_training_experience?",
                    "8. What aspects of the training did you enjoy most?":"what_aspects_of_the_training_did_you_enjoy_most?", "9. Were the training objectives clearly communicated?":"were_the_training_objectives_clearly_communicated?", 
                    "10. How engaging did you find the training sessions?":"how_engaging_did_you_find_the_training_sessions?", "11. How effective were the trainers in delivering the content?":"how_effective_were_the_trainers_in_delivering_the_content?", 
                    "12. How would you rate the training materials provided?":"how_would_you_rate_the_training_materials_provided?", "13. What new skills or knowledge did you acquire from the training?":"what_new_skills_or_knowledge_did_you_acquire_from_the_training?", 
                    "14. How confident do you feel in using technology for learning after the training?":"how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?", "15. What challenges did you encounter while using technology during the training?":"what_challenges_did_you_encounter_while_using_technology_during_the_training?",  
                    "16. How do you plan to apply what you learned in your studies?":"how_do_you_plan_to_apply_what_you_learned_in_your_studies?", "17. What topics would you like to see covered in future training sessions?":"what_topics_would_you_like_to_see_covered_in_future_training_sessions?",
                    "18. Do you have any suggestions to improve the training program?":"do_you_have_any_suggestions_to_improve_the_training_program?", "19. Any additional comments or feedback?":"any_additional_comments_or_feedback?" }, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1982 entries, 0 to 1981
# Data columns (total 46 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   start_time                                                                          1982 non-null   datetime64[ns]
#  1   end_time                                                                            1982 non-null   datetime64[ns]
#  2   1. Name                                                                             1958 non-null   object
#  3   age                                                                                 1957 non-null   object
#  4   gender                                                                              1929 non-null   object
#  5   name_of_school                                                                      1879 non-null   object
#  6   grade_or_class                                                                      1909 non-null   object
#  7   region_of_school                                                                    1936 non-null   object
#  8   how_would_you_rate_the_overall_training_experience?                                 1939 non-null   object
#  9   what_aspects_of_the_training_did_you_enjoy_most?                                    1728 non-null   object
#  10  were_the_training_objectives_clearly_communicated?                                  1922 non-null   object
#  11  how_engaging_did_you_find_the_training_sessions?                                    1923 non-null   object
#  12  how_effective_were_the_trainers_in_delivering_the_content?                          1929 non-null   object
#  13  how_would_you_rate_the_training_materials_provided?                                 1930 non-null   object
#  14  what_new_skills_or_knowledge_did_you_acquire_from_the_training?                     1675 non-null   object
#  15  how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?      1919 non-null   object
#  16  what_challenges_did_you_encounter_while_using_technology_during_the_training?       1384 non-null   object
#  17  how_do_you_plan_to_apply_what_you_learned_in_your_studies?                          1361 non-null   object
#  18  what_topics_would_you_like_to_see_covered_in_future_training_sessions?              1292 non-null   object
#  19  do_you_have_any_suggestions_to_improve_the_training_program?                        1162 non-null   object
#  20  any_additional_comments_or_feedback?                                                1050 non-null   object
#  21  4. Grade/Class                                                                      9 non-null      object
#  22  5. Region of School                                                                 9 non-null      object
#  23  6. How would you rate the overall training experience?                              9 non-null      object
#  24  7. What aspects of the training did you enjoy most?                                 8 non-null      object
#  25  8. Were the training objectives clearly communicated?                               9 non-null      object
#  26  9. How engaging did you find the training sessions?                                 9 non-null      object
#  27  10. How effective were the trainers in delivering the content?                      9 non-null      object
#  28  11. How would you rate the training materials provided?                             9 non-null      object
#  29  12. What new skills or knowledge did you acquire from the training?                 6 non-null      object
#  30  13. How confident do you feel in using technology for learning after the training?  9 non-null      object
#  31  14. What challenges did you encounter while using technology during the training?   9 non-null      object
#  32  15. How do you plan to apply what you learned in your studies?                      5 non-null      object
#  33  16. What topics would you like to see covered in future training sessions?          7 non-null      object
#  34  17. Do you have any suggestions to improve the training program?                    3 non-null      object
#  35  18. Any additional comments or feedback?                                            1 non-null      object
#  36  _id                                                                                 1982 non-null   int64
#  37  _uuid                                                                               1982 non-null   object
#  38  _submission_time                                                                    1982 non-null   datetime64[ns]
#  39  _validation_status                                                                  0 non-null      float64
#  40  _notes                                                                              0 non-null      float64
#  41  _status                                                                             1982 non-null   object
#  42  _submitted_by                                                                       0 non-null      float64
#  43  __version__                                                                         1982 non-null   object
#  44  _tags                                                                               0 non-null      float64
#  45  _index                                                                              1982 non-null   int64
# dtypes: datetime64[ns](3), float64(4), int64(2), object(37)
# memory usage: 712.4+ KB

# %%
df_drop = df.drop(["4. Grade/Class", "5. Region of School", "6. How would you rate the overall training experience?",
             "7. What aspects of the training did you enjoy most?", "8. Were the training objectives clearly communicated?", "9. How engaging did you find the training sessions?",
             "10. How effective were the trainers in delivering the content?", "11. How would you rate the training materials provided?", "12. What new skills or knowledge did you acquire from the training?", 
             "13. How confident do you feel in using technology for learning after the training?", "14. What challenges did you encounter while using technology during the training?",
             "15. How do you plan to apply what you learned in your studies?", "16. What topics would you like to see covered in future training sessions?",
             "17. Do you have any suggestions to improve the training program?", "18. Any additional comments or feedback?", "_id", "_uuid", "_submission_time", "_validation_status", 
             "_notes", "_status", "_submitted_by", "__version__", "_tags", "_index"], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                start_time                end_time            1. Name  age  \
# 0 2024-09-17 10:10:42.110 2024-09-17 10:18:55.756        SAMLA MELODY  11
# 1 2024-09-17 08:54:55.748 2024-09-17 10:30:09.788       MENSAH DENNIS   9
# 2 2024-09-17 10:30:10.002 2024-09-17 10:37:43.941  AMEEVOR EMMANUELLA   9
# 3 2024-09-17 10:37:44.060 2024-09-17 10:48:22.056        DOGBEY BLESS   8
# 4 2024-09-17 10:48:22.264 2024-09-17 11:21:45.844        SACKEY BETTY  11
#
#    gender            name_of_school grade_or_class region_of_school  \
# 0  Female  AKATSI NO.1 BASIC SCHOOL      Primary 2            Volta
# 1    Male        AKATSI NO. 1 BASIC      Primary 2            Volta
# 2  Female        AKATSI NO. 1 BASIC      Primary 2            Volta
# 3  Female                       NaN      Primary 2            Volta
# 4  Female        AKATSI NO. 1 BASIC      Primary 2            Volta
#
#   how_would_you_rate_the_overall_training_experience?  \
# 0                                               Good
# 1                                               Good
# 2                                               Good
# 3                                          Very good
# 4                                          Very good
#
#   what_aspects_of_the_training_did_you_enjoy_most?  ...  \
# 0                                      All aspects  ...
# 1                                           TYPING  ...
# 2                                       EVERYTHING  ...
# 3                                     WHEN WE SANG  ...
# 4                                       EVERYTHING  ...
#
#   how_engaging_did_you_find_the_training_sessions?  \
# 0                                    Very engaging
# 1                                    Very engaging
# 2                                    Very engaging
# 3                                    Very engaging
# 4                                    Very engaging
#
#   how_effective_were_the_trainers_in_delivering_the_content?  \
# 0                                          Effective
# 1                                     Very effective
# 2                                          Effective
# 3                                          Effective
# 4                                     Very effective
#
#   how_would_you_rate_the_training_materials_provided?  \
# 0                                          Very good
# 1                                          Very good
# 2                                               Good
# 3                                          Very good
# 4                                          Very good
#
#   what_new_skills_or_knowledge_did_you_acquire_from_the_training?  \
# 0                                How use  the Tablet
# 1     I CAN NOW TEACH MY PARENTS TO USE THE INTERNET
# 2                               HOW TO WRITE & LEARN
# 3                                      PLAYING GAMES
# 4                                          KIDD. COM
#
#   how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?  \
# 0                                 Somewhat confident
# 1                                          Confident
# 2                                          Confident
# 3                                          Confident
# 4                                          Confident
#
#   what_challenges_did_you_encounter_while_using_technology_during_the_training?  \
# 0                         How to type in the browser
# 1                                      NO CHALLENGES
# 2                                      NO CHALLENGES
# 3                                      NO CHALLENGES
# 4                                      NO CHALLENGES
#
#   how_do_you_plan_to_apply_what_you_learned_in_your_studies?  \
# 0                          Apply in my everyday life
# 1  I WILL CONTINUE TO APPLY IT IN MY STUDIES AT HOME
# 2                                    TO EXPLORE MORE
# 3                            TO EXPLORE THE INTERNET
# 4                                    TO TEACH OTHERS
#
#   what_topics_would_you_like_to_see_covered_in_future_training_sessions?  \
# 0                                     Cyber security
# 1  TO EXPLORE THE INTERNET WITH SEARCH ENGINES FO...
# 2                            THE USE OF THE INTERNET
# 3                  WHERE WE WERE ASKED TO TYPE WORDS
# 4                               ANY NEW DISCORVERIES
#
#   do_you_have_any_suggestions_to_improve_the_training_program?  \
# 0                             Everyone to get Tablet
# 1                    THE TRAINING SHOULD BE REPEATED
# 2                                     NO SUGGESTIONS
# 3                                     NO SUGGESTIONS
# 4                                     NO SUGGESTIONS
#
#   any_additional_comments_or_feedback?
# 0              Everyone should involve
# 1                  I LOVE THE TRAINING
# 2                          NO COMMENTS
# 3               NO ADDITIONAL COMMENTS
# 4                          NO COMMENTS
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#                           start_time                       end_time
# count                           1982                           1982
# mean      2024-09-21 10:12:53.702048  2024-09-21 11:09:04.956091136
# min       2024-09-17 06:44:23.001000     2024-09-17 06:51:51.590000
# 25%    2024-09-18 14:52:34.972499968  2024-09-18 15:06:30.503249920
# 50%    2024-09-19 21:00:37.370500096  2024-09-20 09:37:57.708499968
# 75%    2024-09-24 14:18:34.969499904  2024-09-24 14:29:41.175749888
# max       2024-10-03 19:13:54.022000     2024-10-03 19:15:16.860000

# %%
df.isna().sum()
# Out:
# start_time                                                                          0
# end_time                                                                            0
# 1. Name                                                                            24
# age                                                                                25
# gender                                                                             53
# name_of_school                                                                    103
# grade_or_class                                                                     73
# region_of_school                                                                   46
# how_would_you_rate_the_overall_training_experience?                                43
# what_aspects_of_the_training_did_you_enjoy_most?                                  254
# were_the_training_objectives_clearly_communicated?                                 60
# how_engaging_did_you_find_the_training_sessions?                                   59
# how_effective_were_the_trainers_in_delivering_the_content?                         53
# how_would_you_rate_the_training_materials_provided?                                52
# what_new_skills_or_knowledge_did_you_acquire_from_the_training?                   307
# how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?     63
# what_challenges_did_you_encounter_while_using_technology_during_the_training?     598
# how_do_you_plan_to_apply_what_you_learned_in_your_studies?                        621
# what_topics_would_you_like_to_see_covered_in_future_training_sessions?            690
# do_you_have_any_suggestions_to_improve_the_training_program?                      820
# any_additional_comments_or_feedback?                                              932
# dtype: int64

# %%
df.dropna(how='all')
# Out:
#                   start_time                end_time  \
# 0    2024-09-17 10:10:42.110 2024-09-17 10:18:55.756
# 1    2024-09-17 08:54:55.748 2024-09-17 10:30:09.788
# 2    2024-09-17 10:30:10.002 2024-09-17 10:37:43.941
# 3    2024-09-17 10:37:44.060 2024-09-17 10:48:22.056
# 4    2024-09-17 10:48:22.264 2024-09-17 11:21:45.844
# ...                      ...                     ...
# 1977 2024-09-20 19:04:43.866 2024-09-20 19:08:42.196
# 1978 2024-09-20 19:08:42.290 2024-09-20 19:08:48.246
# 1979 2024-09-20 19:08:48.335 2024-09-20 19:08:56.386
# 1980 2024-09-20 19:08:56.464 2024-09-20 19:09:50.252
# 1981 2024-10-03 19:13:54.022 2024-10-03 19:15:16.860
#
#                             1. Name   age  gender            name_of_school  \
# 0                       SAMLA MELODY   11  Female  AKATSI NO.1 BASIC SCHOOL
# 1                      MENSAH DENNIS    9    Male        AKATSI NO. 1 BASIC
# 2                 AMEEVOR EMMANUELLA    9  Female        AKATSI NO. 1 BASIC
# 3                       DOGBEY BLESS    8  Female                       NaN
# 4                       SACKEY BETTY   11  Female        AKATSI NO. 1 BASIC
# ...                              ...  ...     ...                       ...
# 1977  Yvonne Nhyira Ama Twum-Barimah   11  Female      Elmina Methodist JHS
# 1978                             NaN  NaN     NaN                       NaN
# 1979                             NaN  NaN     NaN                       NaN
# 1980  Yvonne Nhyira Ama Twum-Barimah   11  Female                       NaN
# 1981                             NaN  NaN     NaN                       NaN
#
#      grade_or_class region_of_school  \
# 0         Primary 2            Volta
# 1         Primary 2            Volta
# 2         Primary 2            Volta
# 3         Primary 2            Volta
# 4         Primary 2            Volta
# ...             ...              ...
# 1977          JHS 2          Central
# 1978            NaN              NaN
# 1979            NaN              NaN
# 1980          JHS 2          Central
# 1981            NaN              NaN
#
#      how_would_you_rate_the_overall_training_experience?  \
# 0                                                  Good
# 1                                                  Good
# 2                                                  Good
# 3                                             Very good
# 4                                             Very good
# ...                                                 ...
# 1977                                          Excellent
# 1978                                                NaN
# 1979                                                NaN
# 1980                                          Excellent
# 1981                                                NaN
#
#      what_aspects_of_the_training_did_you_enjoy_most?  ...  \
# 0                                         All aspects  ...
# 1                                              TYPING  ...
# 2                                          EVERYTHING  ...
# 3                                        WHEN WE SANG  ...
# 4                                          EVERYTHING  ...
# ...                                               ...  ...
# 1977                         How to turn on your wifi  ...
# 1978                                              NaN  ...
# 1979                                              NaN  ...
# 1980                                How to usetheInte  ...
# 1981                                              NaN  ...
#
#      how_engaging_did_you_find_the_training_sessions?  \
# 0                                       Very engaging
# 1                                       Very engaging
# 2                                       Very engaging
# 3                                       Very engaging
# 4                                       Very engaging
# ...                                               ...
# 1977                                    Very engaging
# 1978                                              NaN
# 1979                                              NaN
# 1980                                              NaN
# 1981                                              NaN
#
#      how_effective_were_the_trainers_in_delivering_the_content?  \
# 0                                             Effective
# 1                                        Very effective
# 2                                             Effective
# 3                                             Effective
# 4                                        Very effective
# ...                                                 ...
# 1977                                          Effective
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      how_would_you_rate_the_training_materials_provided?  \
# 0                                             Very good
# 1                                             Very good
# 2                                                  Good
# 3                                             Very good
# 4                                             Very good
# ...                                                 ...
# 1977                                         Excellent
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      what_new_skills_or_knowledge_did_you_acquire_from_the_training?  \
# 0                                   How use  the Tablet
# 1        I CAN NOW TEACH MY PARENTS TO USE THE INTERNET
# 2                                  HOW TO WRITE & LEARN
# 3                                         PLAYING GAMES
# 4                                             KIDD. COM
# ...                                                 ...
# 1977                                                NaN
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?  \
# 0                                    Somewhat confident
# 1                                             Confident
# 2                                             Confident
# 3                                             Confident
# 4                                             Confident
# ...                                                 ...
# 1977                                          Confident
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      what_challenges_did_you_encounter_while_using_technology_during_the_training?  \
# 0                            How to type in the browser
# 1                                         NO CHALLENGES
# 2                                         NO CHALLENGES
# 3                                         NO CHALLENGES
# 4                                         NO CHALLENGES
# ...                                                 ...
# 1977                               More learning skills
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      how_do_you_plan_to_apply_what_you_learned_in_your_studies?  \
# 0                             Apply in my everyday life
# 1     I WILL CONTINUE TO APPLY IT IN MY STUDIES AT HOME
# 2                                       TO EXPLORE MORE
# 3                               TO EXPLORE THE INTERNET
# 4                                       TO TEACH OTHERS
# ...                                                 ...
# 1977                                             Revice
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      what_topics_would_you_like_to_see_covered_in_future_training_sessions?  \
# 0                                        Cyber security
# 1     TO EXPLORE THE INTERNET WITH SEARCH ENGINES FO...
# 2                               THE USE OF THE INTERNET
# 3                     WHERE WE WERE ASKED TO TYPE WORDS
# 4                                  ANY NEW DISCORVERIES
# ...                                                 ...
# 1977                                                ICT
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      do_you_have_any_suggestions_to_improve_the_training_program?  \
# 0                                Everyone to get Tablet
# 1                       THE TRAINING SHOULD BE REPEATED
# 2                                        NO SUGGESTIONS
# 3                                        NO SUGGESTIONS
# 4                                        NO SUGGESTIONS
# ...                                                 ...
# 1977   To help younger children how to use the Internet
# 1978                                                NaN
# 1979                                                NaN
# 1980                                                NaN
# 1981                                                NaN
#
#      any_additional_comments_or_feedback?
# 0                 Everyone should involve
# 1                     I LOVE THE TRAINING
# 2                             NO COMMENTS
# 3                  NO ADDITIONAL COMMENTS
# 4                             NO COMMENTS
# ...                                   ...
# 1977                      To learn harder
# 1978                                  NaN
# 1979                                  NaN
# 1980                                  NaN
# 1981                                  NaN
#
# [1982 rows x 21 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1977    False
# 1978    False
# 1979    False
# 1980    False
# 1981    False
# Length: 1982, dtype: bool

# %%
df.columns
# Out:
# Index(['start_time', 'end_time', '1. Name ', 'age', 'gender', 'name_of_school',
#        'grade_or_class', 'region_of_school',
#        'how_would_you_rate_the_overall_training_experience?',
#        'what_aspects_of_the_training_did_you_enjoy_most?',
#        'were_the_training_objectives_clearly_communicated?',
#        'how_engaging_did_you_find_the_training_sessions?',
#        'how_effective_were_the_trainers_in_delivering_the_content?',
#        'how_would_you_rate_the_training_materials_provided?',
#        'what_new_skills_or_knowledge_did_you_acquire_from_the_training?',
#        'how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?',
#        'what_challenges_did_you_encounter_while_using_technology_during_the_training?',
#        'how_do_you_plan_to_apply_what_you_learned_in_your_studies?',
#        'what_topics_would_you_like_to_see_covered_in_future_training_sessions?',
#        'do_you_have_any_suggestions_to_improve_the_training_program?',
#        'any_additional_comments_or_feedback?'],
#       dtype='object')

# %%
df.describe()
# Out:
#                           start_time                       end_time
# count                           1982                           1982
# mean      2024-09-21 10:12:53.702048  2024-09-21 11:09:04.956091136
# min       2024-09-17 06:44:23.001000     2024-09-17 06:51:51.590000
# 25%    2024-09-18 14:52:34.972499968  2024-09-18 15:06:30.503249920
# 50%    2024-09-19 21:00:37.370500096  2024-09-20 09:37:57.708499968
# 75%    2024-09-24 14:18:34.969499904  2024-09-24 14:29:41.175749888
# max       2024-10-03 19:13:54.022000     2024-10-03 19:15:16.860000

# %%
# Remove rows with NaN values in the 'Age' column
df = df.dropna(subset=['age'])

# %%
import pandas as pd
from your_script import remove_unwanted_age_values

def remove_unwanted_age_values(df):
    """Removes unwanted values from the 'age' column of a DataFrame.

    Args:
        df (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: The DataFrame with the unwanted values removed from the 'age' column.
    """

    unwanted_values = ['nan', 'THIRTEEN', 'Sixteen', '14years', 'Enchi RC',
                       '15 years', 'twelve years', '12 years', '13 years old',
                       '¹²', '11years', '12year', '12a', 'Eleven']

    # Create a boolean mask to identify rows with unwanted values
    mask = df['age'].isin(unwanted_values)
    

    return df_cleaned

# %%
df = remove_unwanted_age_values(df)

# %%
df["age"].unique()
# Out:
# array(['11', '9', '8', '10', '13', '7', '12', '6', '14', '15', '20', '16',
#        '31', '57', '34', '37', '46', '19', '17', '22', '1', '18', '38',
#        '5', '21', '42'], dtype=object)

# %%
training_experience = df["how_would_you_rate_the_overall_training_experience?"].value_counts()
print(training_experience)

plt.figure(figsize = (12,6))
sns.barplot(data = training_experience)
plt.title("Overall Training experience")
plt.xlabel("How would you rate the overall training experience")
plt.savefig("overall_experience.png")
plt.show()
# Out:
# how_would_you_rate_the_overall_training_experience?
# Excellent    1113
# Very good     627
# Good          172
# Poor            5
# Name: count, dtype: int64

# %%
df["what_aspects_of_the_training_did_you_enjoy_most?"].unique()
# Out:
# array(['All aspects', 'TYPING', 'EVERYTHING', 'WHEN WE SANG',
#        'Kiddconner', 'Video part', 'Typing', 'THE BROWSER',
#        'Cyber security', 'Drawing', nan, 'Games', 'Research',
#        'Internet surfing', 'Internet browsing part',
#        'Browsing the internet', 'Fun games', 'MONKEY SEE MONKEY DO',
#        'Navigating through the apps on the tablets',
#        'Typing using search engine', 'Uses of Internet',
#        'Accessing the internet',
#        'How I access the internet for first time', 'hands-on', 'hand-on',
#        'Practicals', 'practical', 'The practical session',
#        'Pratical session', 'Practical Lessions', 'practical class',
#        'Everything able the training', 'Demonstration session',
#        'The dancing and the going through the tablet',
#        'Every aspect of it', 'All', 'Visiting the internet',
#        'EVERY ASPECT', 'WEB BROWSER', 'WHEN WE WERE USING THE TABLET',
#        'Cyber Security', 'Khan academy', 'Exploring the search engines',
#        'Using web browsers', 'Using tablets', 'Exploring the internet',
#        'Using the search engine', 'Cybersecurity',
#        'Searching for something', 'cyber security',
#        'Using the search engines',
#        'When we were allowed to search for something on the internet',
#        'Search engines', 'search engine', 'The part they engaged us',
#        'The explanations', 'The explanation part', 'Creating passwords',
#        'The part they teach how to search things online', 'Search engine',
#        'How to search', 'Searching for things online',
#        'Search engine and how to connect to the internet using the WiFi',
#        'Connecting to WIFI', 'Turning on and off the tablet',
#        'Connecting to the Wi-Fi', 'The navigating part',
#        'The search engine', 'Using  the search engine', 'DRAWING',
#        'Search engine and connecting to the Wifi', 'Using search engine',
#        'Connecting to the web browser', 'Turning on and off tablet',
#        'Khan Academy', 'Connect to the Wifi',
#        'HOW TO CONNECT TO THE INTERNET USING DEVICES',
#        'HOW TO USE THETNET', 'Turning on your application',
#        'Kidis corner', 'Kids corner', 'Internet',
#        'How To search using the web browser', 'How to type words',
#        'Kids Corner', 'How to search on internet', 'Kids conner',
#        'Videos', 'Kiddle. Com', 'Searching online',
#        'Connecting to the WiFi', 'Navigating through the internet',
#        'Downloading apps', 'Downloading the apps',
#        'How to get information from the internet',
#        'How to get information', 'Kiddle',
#        'Searching for information online',
#        'I like the part we search for kiddle',
#        'How the learners were able to use the tablet',
#        'Helping my students to use the tablets and do research on their own own.',
#        'Downloading APK', 'How to use the apps', 'Cybercrimes',
#        'Search for online information',
#        'VARIOUS APPLICATIONS THAT AIDS LEARNING', 'Use of tablets',
#        'Typing information into the web', 'Teaching using the tablets',
#        'Using the tablets', 'Leaning on cyber security', 'Cybercrime',
#        'How to use the internet in learning',
#        'HOW TO USE THE INTERNET TO LEARN', 'Kidscorner', 'Amanda’s Story',
#        'Using the Internet', "Chicken dance and Amanda's story",
#        'Searching for help using the browser',
#        'Using the tablet for search things on the internet',
#        "Amanda's story and chicken dance", 'Searching',
#        'Controlling kids from using internet.',
#        'SEARCHING FOR APPLICATIONS',
#        'Searching for things using the Internet',
#        'Typing using the tablet.',
#        'Using the tablet to learn how to search for information',
#        'Using the tablets to learn', 'How to google',
#        'Search on the internet', 'How to search on web',
#        'How to use the search engines on the tablet', 'cuber security',
#        'Manipulating the tablets', 'Word browser', 'Using internet',
#        'THE WIRELESS CONNECTIONS, THUS HOTSPOT AND OTHERS',
#        'I enjoyed how to operate the tablet', 'Training on the tablet',
#        'Using the web browser', 'Accessing the net', 'Web browser',
#        'Using the Web browser to do search and learn',
#        'How to search for information on the internet',
#        'Web browser and the internet', 'Usage of tablet',
#        'The use of the tablet', 'The kids Corner painting',
#        'CYBER SECURITY', 'How the learning was facilitated',
#        'The Web browsing', 'All the aspects', 'How to use the Internet',
#        'Acronyms and their meaning',
#        'Staying safe online & Chicken dance', 'Using the kids corner',
#        'All except cyber security', 'How to use a tablet & Chicken dance',
#        'DOWNLOADING APPLICATIONS', 'The kids corner', 'Stem',
#        'The demonstration sessions', 'Not Cyber Security', 'Cyber Crime',
#        'Typing aspect', 'The video show', 'Cyber crime', 'Identity curve',
#        'The browsing part', 'How to search things on the Internet',
#        'CYBER SECURITY AND HOW TO USE THE WEB TO LEARN',
#        'The Internet search and connecting hotspot', 'STEM',
#        'How to search on the Internet', 'Kindle. Co', 'Everything',
#        'Knowing  how secure my password  is', 'The viedo aspect',
#        'The Cyber security aspect',
#        'Not sharing personal information online', 'About cyber security',
#        'Chicken Dance', 'The cyber security part', 'The stem app', 'good',
#        'Cyber security.',
#        'Introduction to seach engines and cyber security',
#        'How to prevent people from hacking your account and checking the secure rate of your password',
#        'How to prevent people from hacking your phone and checking the secure rate of your password',
#        'Cyber groomer', 'The part about cyber security',
#        'I enjoyed the part we danced the chicken dance', 'chiken dance',
#        'The video aspect',
#        'Training on how to protect information on internet',
#        'The chicken dance', 'dancing',
#        'The part that we must not put everything we get on the internet.',
#        'How i need to be careful whenever am using the Internet',
#        'The teaching sessions', 'Stem apps', 'Home works',
#        'The part about cyberbullying', 'Stem App', 'chicken Dance',
#        'Discussion was the most enjoyable one', 'Discussion',
#        'Chicken dance', 'Coding', 'TheSTEM app', 'The STEM Apps',
#        'the aspect i enjoyed most is the chicken dance',
#        'Cyber security for kids', 'Computing',
#        'Learning about cyber crime', 'Learning', 'al aspects',
#        'How they Ask us questions', 'Video',
#        'When I was watching the video', 'STEM APP', 'STEM App',
#        'Discussion part',
#        'I enjoyed the part we talked about STEM Applications',
#        'CYBERCRIME', 'Web Browser', 'Digital skills training', 'NASA App',
#        'Technical', 'CYBER security', 'When we were watching the video',
#        'The cyber bullying', 'How to have access to your phone',
#        'Password protection', 'When I was watching vedio', 'Technology',
#        'the video', 'STEM apps', 'the stem apps', 'Www. Kiddle.co',
#        'web  browser', 'practical part', 'kiddle', 'The Training Part',
#        'languages of the Internet', 'The video', 'GAMES',
#        'Being an expert in coding',
#        'The chicken dance and the password creation', 'practical parts',
#        'The end of the program',
#        'how to protect your self form wordbrowzer', 'knowledge',
#        'the browsing aspect', 'URL', 'The internet',
#        'How to use cyber  security', 'the kiddle searching',
#        'The exercise place', 'the end of the program', 'cyber', 'Dance',
#        'The practical aspect', 'LEARNING OF STEM APP',
#        'The dancing aspect',
#        'The use of the Tablet to search for information online',
#        'STEM APPs', 'Tablet on and off, chicken dance', 'stem apps',
#        'Engineering', 'Tablet on and off', 'tablet operation',
#        'tablet on and off', 'How to protect your phone',
#        'Switching the Tablet on and off and connecting to the Internet',
#        'Using the Tablet to connect to the wife network and searching for information online',
#        'Using the Tablet to search for and download STEM apps',
#        'Using the Tablet to download apps', 'The Cybersecurity',
#        "The chicken dance and Amanda's story", "Amanda's Story",
#        'How to use the Tablet to download apps and how to search engine to search for information online',
#        'Cyber Security For Kids',
#        'Using the Tablet for search for information online',
#        'The use of the Tablet to connect to the wireless network and access the Internet',
#        'Using the Tablet to find information online',
#        'Switching on and off the Tablet', 'cybersecurity', 'apps',
#        'The using of tablet make me understand the work',
#        'Cybersecurity side', 'Cyber security side',
#        'The usage of the tablet', 'The cyber security', 'Play game',
#        'Usage of the tablets', 'The cyber security side',
#        'How to use internet to learn', 'Using  of  the tablets',
#        'Usage of tablets', 'The using of the tablets', 'Using the tablet',
#        'Tablet and chicken', 'teaching', 'Stem apps, chicken dance',
#        'Teaching and chicken dance', 'chicken dance',
#        'Safe search and chicken dance',
#        'Using the tablet & Chichen dance', 'Chicken dance and videos',
#        'Stem app',
#        'All of them video on cyber security and chicken dance',
#        'Video on cyber security', 'Using the tablet and chicken dance',
#        'How to use the tablet and chicken dance',
#        'Stay safe online for kids', 'Browsing', 'Internet safety video',
#        'Searching on the internet', 'How to use the tablet',
#        'Avoiding sharing our pictures online',
#        'How to switch on and off the Tablet',
#        'Using the Tablet to color an image',
#        'Using the Internet to search for information',
#        'Staying safe online', 'Maths games', 'Connecting to the internet',
#        'How to use the computer', 'Using the kid safe search engines',
#        'Amanda’s story', 'the wifi', 'Turning on and off the Tablet',
#        'khan academy', 'Searching for information on the Internet',
#        'How to connect to internet', 'Maths game',
#        'when we were using the tablet', 'Practical',
#        'the dance and practical class', 'practice', 'Practical part',
#        'khan property', 'Cyber security f', 'Maths',
#        'How to no and off a tablet', 'Browser app',
#        'BROWSERS APPLICATION', 'Internet and passwors',
#        'using the www.kiddle.co', 'How to go to the internet.',
#        'how to search on internet', 'I learnt About internet connection',
#        'We were given the opportunity to search',
#        'Searching for information', 'the web broswer',
#        'How to refuse crime in the society', 'The  chicken dance',
#        'khan acadamy', 'www.kiddle.co', 'who to concert to the internet',
#        'The aspects l enjoyed most is where we where learning about how to search on brows',
#        'Sporty', 'The tablet  using', 'the tablet using',
#        'Dacing  aspects', 'The vibrator',
#        'I  have learn more about browsers and the tablets and internet',
#        'the Searching Aspect',
#        'when they gave us the opportunity to use the tablets',
#        'Cyber  security', 'How to on and off the tablet', 'by suching',
#        'How to search for information and the dancing at the end',
#        'How to contact to internet', 'How to tapy a patin', 'Browsers',
#        'Dancing part', 'The dancing', 'On and off tablet',
#        'how to the internet', 'how to contact to internen',
#        'Practical and dancing', 'Practising', 'Practise', 'all',
#        'Praticals', 'Hands-on', 'everything', 'Practice', 'Yes',
#        'Downloading  apps', 'Teoss', 'When we went to the browser',
#        'Learning online', 'Using a website', 'Using websites', 'TeOSS',
#        'Free fire', 'The best', 'Using the wifi to access internet',
#        'Searching on online', 'TEOSS', 'The Usage of the Internet',
#        'When we were assigned to search something from our web browser',
#        'Looking at different types of kids web browsers',
#        'TeOSS training program',
#        'Learning how to use the internet for education',
#        'World Wide Web and safe kids search', 'Internet Connection',
#        'I enjoy the TeOSS about the STEM', 'How gadgets are used', 'Ict',
#        'The informations they gave was good',
#        'Internet or online learning', 'E-learning', 'TeOSS training',
#        'The usage of the Internet', 'The TeOSS', 'English',
#        'Searching on the Google chrome', 'Introducing as to the Internet',
#        'WiFi connection', 'Download app', 'Internet connectivity',
#        'Digital skills', 'Teaching', 'Every part',
#        'How to use your phone',
#        'Knowing apps that will help you to learn', 'Gaming',
#        'The use of gadget to learn', 'E.learning', 'RME',
#        'Learning the games', 'How to use your', 'STEM APPS',
#        'When we were taught some new learning apps to help us learn',
#        'How to learn in the internet',
#        'I really enjoyed the STEM part of the training', 'The STEM',
#        'Giving hotspot to resuch', 'Every thing', 'Duolingo',
#        'When they told as to download the stem network',
#        'When they told as to go and search  the NASA',
#        'The one they said we should look the full meaning of NASA',
#        'How to access the internet', 'Practical aspect', 'Coding Apps',
#        'Wifi', 'The meaning of NASA', 'Internet part',
#        'Learning the STEM apps', 'Web browser and the STEM',
#        'Teaching as to download educative apps',
#        'How to be safe on the Internet', 'On web browsers',
#        'The stem apps used in coding,e.t.c', 'Connecting to the Internet',
#        'The learning and practicing of the Web browsers',
#        'Connection to WiFi network', 'Learning about the Internet',
#        'Mathematics', "I enjoyed the internet's explanation",
#        'Using the  Internet', 'How to open a website',
#        'Whiles using the device', 'ITS WAS INTERACTIVE',
#        'Using the internet', 'INTERNET',
#        'The interaction with the network and the free WiFi',
#        'WHEN WE USE THE TABLET TO BROWSE KIDDLE',
#        'HOW TO LEARN ON INTERNET', 'HOW TO TYPE',
#        'DURING THE INTERNET SEARCH', 'HOW TO SEARCH USING THE INTERNET',
#        'HOW TO SEARCH ONLINE', 'THE GAMES', 'HOW TO DOWNLOAD',
#        'DURING THE DRAWING', 'Good', 'Internet Aspect',
#        'Practical sessions', 'Cyber ɓuli',
#        'I enjoyed the cyber Security part with all my energy',
#        'I enjoyed the cyber secuiry aspect of the lesson',
#        'Using kids.co to search for information',
#        'Searching the internet for information using kindle.co',
#        'The teaching', 'Bringing tablets to be taught how to use it',
#        'Search Engine',
#        'Switching the tablet on and connecting it to the internet',
#        'The use of tablet for learning', 'How to search on the web',
#        'Sesrch engines', 'Using search engines',
#        'How to use the internet to watch videos', 'Google chrome',
#        'Connecting on the internet and browsing the internet', 'no',
#        'STEM Apps', 'Search engine or web browser', 'Web search', 'STEM.',
#        'USING THE TABLET.', 'How to boot a tablet', 'Game',
#        'How tobuse a tablet', 'Installing STEM applications and using it',
#        'Install stems apps and using it', 'The videos',
#        'Installing applications and using them',
#        'Downloading of BECE app', 'Break Games', 'Settings of wifi',
#        'Installing and using the Stem applications', 'Pictures',
#        'Installing parts', 'Installing and using applications',
#        'The educational apps', 'Creating strong passwords',
#        'How to get learning apps',
#        'Installing and using stem applications', 'using the tablet',
#        'Search for learning apps', 'the internet browser',
#        'Google Search', 'How to turn on and off a tablet',
#        'few tablets were available for us', 'How to use tablet',
#        'Practicing using the tablet', 'The video on cybercrime',
#        'How to on a wifi', 'when we are using the tablet',
#        'Installing and using Stem apps', 'Presentation',
#        'Digital Footprint', 'Installing and using stem apps',
#        'Utilizing the Internet for learning',
#        'How to store apps on tablet', 'Cybersecurity videos', 'Dancing',
#        'The involvement of the student', 'An ICT',
#        'Getting to use the tablet to access the Internet',
#        'How to use a tablet', 'Online search', 'the chicken dance',
#        'The security videos and chicken dance', 'getting to know the web',
#        'Involvement of students', 'How to search apps on Internet',
#        'Internet access', 'Involvement of students in the presentation',
#        'Cyber grooming', 'CYBERCRIME VIDEO', 'connecting the web',
#        'Distribution of tablets',
#        'How to use tablet to search information',
#        'questioning and answering session', 'WRB BROWSER',
#        'Questioning and Answering Session', 'The use of tablets',
#        'search online', 'CHICKEN DANCE',
#        "Chicken Dance and using the 'Spelling and Phonics' STEM APP",
#        "Using the 'Spelling and Phonics' STEM APP", 'The cyber video',
#        'DOGITAL FOOTPRINT', 'How to search for programs',
#        'how to use the internet', 'SYSTEM',
#        'How to switch on and off of the tablet', 'Cyber video',
#        'Learning how to use the internet and what we should do and what we should not do',
#        'The one watching videos',
#        'Student participation in the presentation',
#        'How to use tablet to search for apps', 'Stem maths content',
#        'Stem education contents', 'The one watching video',
#        'Use of the tablets for learning', 'Accessing the internet.',
#        'Surfing the internet', 'Internet accessibility',
#        'Involvement of students in the practice',
#        'how to connect to internet', 'How to open the Internet',
#        'Internet assessment', 'how to assess internet',
#        'Accessing the internet and interactive sections. I was able to ask questions and get answers.',
#        'Connecting the internet',
#        "The access to the devices was interesting ' I feel good'",
#        'How to access the Internet and search for information',
#        'Connecting the the WiFi to be able to use the browser',
#        'How use tablet', 'How to open programs', 'being able to browse',
#        'I really enjoyed the cyber security class on how to protect yourself from the internet.',
#        'Accessing the Internet', 'How to search on the internet',
#        'How to open the web browser', 'where we were able to browse',
#        'The time we had access to the Internet', 'Connecting to internet',
#        'Cyber Security.', 'the browsing',
#        'How to search with the search engine',
#        'Learning about the internet', 'Thr Internet',
#        'I enjoyed all the aspects of the training.',
#        'How to connect internet',
#        'How to go to the Internet and also cyber ctimr',
#        'I enjoyed using the accessibility feature to navigate the tablet',
#        'All the aspects of the training it was very educative.',
#        'Connecting Wi-Fi', 'Cyber bullying and how to use the tablets',
#        'when i was using the tablet', 'Restarting the device',
#        'How to use Browsers', 'Turning the tablet on and off',
#        'How to create strong passwords', 'Restarting the tablet',
#        'How to use tablet for browsing', 'Web browsing',
#        'Internet browsing', 'Connecting to the internet using tablet',
#        'Accessing internet', 'How to use internet',
#        'How to restart a tablet', 'Navigating the internet',
#        'Hands on feel of how to use the tablet',
#        'When we were studying the Internet', 'The practical',
#        'Using the tablet to search on the internet',
#        'How to be safe on the internet', 'How to connect WiFi',
#        'Videos on cyber security', 'How to connect to the Internet',
#        'How to put password on your device',
#        'Installing and working with STEM apps', 'Being safe on line',
#        'Stem education', 'How to use the browser', 'Cyber bully',
#        'world wide web', 'Using our tablets', 'Using the stem apps',
#        'Downloading the stem apps',
#        'Learning about kiddle.co and the other kiddies search engines',
#        'Playing with the stem apps',
#        'Using our tablets to connect to the internet',
#        'Using the stem apps as a learning aid', 'Downloading stem apps',
#        'How to access the Internet', 'How to learn on the Internet',
#        'How to use the search engines', 'Typing on the tablet',
#        'How to turn on the tablet', 'Knowing about STEM',
#        'search engines', 'Learning about Stem', 'Downloading STEM apps',
#        'How to search online', 'searching online', 'typing on the device',
#        'ICT', 'Cyber security aspect', 'Cybercrime video', 'dance',
#        'opening apps like YouTube', 'Internet Browser', 'www',
#        'the movie about cyber security',
#        'How to connect data to a computer', 'locking phone with password',
#        'opening of apps',
#        'Using the video to demonstrate the cyber security aspect of the training',
#        'How to launch app', 'Careful using ICT tools',
#        'Using video to demonstrate the cyber security aspect of the training',
#        'Search', 'Planning games', 'Reading', 'Connecting of Internet',
#        'Downloading Apps', 'Playing with the tablet', 'Downloading games',
#        'The tablet', 'The Stem App', 'The practice',
#        'Using the tablet and the woman talking',
#        'During the practical session', 'Using the Tablet',
#        'Learning about internet', 'The tablet part', 'Google searching',
#        'I learnt how to use a tablet', 'Using ICT tools for learning',
#        'Important of putting password on your phone',
#        'The cyber security aspect',
#        'Enjoy the video about cyber security aspect', 'CYBERSECURITY',
#        'engineering', 'Meaning Of STEM', 'how to use the tablet',
#        'The videos and cyber security', 'video aspect',
#        'How to search for YouTube', 'Web browser to search',
#        'Cyber bullying', 'Stem  apps', 'In mathematics', 'video',
#        'cyber security awareness', 'The moves', 'Digital footprint',
#        'Watch video', 'AII', 'The dance moves', 'The dance', 'ALL',
#        'Noyhing', 'I learnt about WWW', 'The first aspects',
#        'Video about cyber security', 'cybergrooming', 'cyber grooming',
#        'I learnt how to use the website',
#        'When we were watching the movie', 'non',
#        'Was of connecting the internet', 'All the subjects', 'Conclusion',
#        'The STEM part', 'Watching videos', 'Watching video',
#        'Installing and playing stem games',
#        'Installing and using apps on tablets', 'Playing STEM games',
#        'Watching cybersecurity videos', 'Using stem apps on the tablet',
#        'Using STEM applications to learn', 'I liked using the tablet',
#        'Using the tablet and the accessibility',
#        'Using STEM applications', 'Using STEM apps to learn',
#        'Going to the internet with the tablet',
#        'Using Stem apps to learn',
#        'Installing and using STEM applications',
#        'Installing and using STEM apps', 'Installing and using STEM appa',
#        'Using our tablet', 'Using the web browser for kids',
#        'Watching the video on cybersecurity',
#        'Learning about the stem apps', 'Learning about cybersecurity',
#        'Learning about the search engine for kids',
#        'Using the tablet to download stem apps',
#        'Learning to turn on and off the tablet',
#        'Turning on and off our tablets', 'Connecting to a wifi network',
#        'How to connect to the internet',
#        'How to turn on and off our tablets',
#        'How to protect ourself on the internet',
#        'How to use the kiddle.co search engine to search for information on the internet',
#        'Learning to turn on and off our tablet',
#        'Learning how to turn on and off our tablets',
#        'Turning on and off our tablet', 'Turning off and on our tablet',
#        'How to turn on your wifi', 'How to usetheInte'], dtype=object)

# %%
training_aspect = df["what_aspects_of_the_training_did_you_enjoy_most?"]

# Join all responses into a single string
text = " ".join(training_aspect.dropna())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, random_state=40).generate(text)

# Plot the word cloud
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("Aspect of training enjoyed most")
plt.axis("off")
plt.savefig("aspect_training.png")
plt.show()

# %%
plt.figure(figsize = (15,6))
sns.histplot(data = df["were_the_training_objectives_clearly_communicated?"])
plt.title("Training objectives clearly communicated?")
plt.xlabel("objectives clearly communicated?")
plt.savefig("train_objs.png")
plt.show()

# %%
engaging_res = df["how_engaging_did_you_find_the_training_sessions?"].value_counts()

plt.figure(figsize = (15,10))
plt.pie(engaging_res, labels=engaging_res.index, autopct='%1.1f%%')
plt.title("Engagement with Training Sessions")
plt.savefig("engagement.png")
plt.show()

# %%
df["how_effective_were_the_trainers_in_delivering_the_content?"].unique()
# Out:
# array(['Effective', 'Very effective', 'Somewhat effective', nan,
#        'Not effective'], dtype=object)

# %%
effective_delivery = df["how_effective_were_the_trainers_in_delivering_the_content?"].value_counts()

plt.figure(figsize = (15,10))
plt.pie(effective_delivery, labels=effective_delivery.index, autopct='%1.1f%%')
plt.title("Effective in deliverying of content")
plt.savefig("effective_deli.png")
plt.show()

# %%
training_materials = df["how_would_you_rate_the_training_materials_provided?"].value_counts()

plt.figure(figsize = (15,7))
sns.barplot(data=training_materials)
plt.title("Rating of training materials provided")
plt.xlabel("How would you rate the training materials provided")
plt.savefig("training_materials.png")
plt.show()

# %%
new_skills = df["what_new_skills_or_knowledge_did_you_acquire_from_the_training?"]

# Join all responses into a single string
text = " ".join(new_skills.dropna())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, random_state=42).generate(text)

# Plot the word cloud
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("New skills or knowledge acquired from training")
plt.axis("off")
plt.savefig("new_skills.png")
plt.show()

# %%
confident_using_tech = df["how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?"].value_counts()

plt.figure(figsize = (15,10))
plt.pie(confident_using_tech, labels=confident_using_tech.index, autopct='%1.1f%%')
plt.title("How confident using Technology for learnig after the training")
plt.savefig("confi_using_tech.png")
plt.show()

# %%
df["what_challenges_did_you_encounter_while_using_technology_during_the_training?"].unique()
# Out:
# array(['How to type in the browser', 'NO CHALLENGES', 'Spelling',
#        'Internet problems', 'Light out', 'NAVIGATING', 'Power outage',
#        nan, 'Power out', 'NOT VERY WELL UNDERSTOOD', 'Navigating the app',
#        'Emergency Light out', 'frequent light out', 'light out',
#        'no more time', 'light off', 'Unstable internet connectivity',
#        'Inadequate laptops', 'Light Off',
#        'Lack of internet connectivity.  Not being able to fully utilize the stem app',
#        'our light was going off all the time', 'Internet',
#        'Internet connectivity', 'Internet and limited tablet',
#        'Emergency light out',
#        'Internet connectivity and limited number of tablets',
#        'NETWORK CHALLENGE', 'NETWORK PROBLEMS',
#        'I DID NOT ENCOUNTER ANY CHALLENGE', 'How to open the tablet',
#        'how to open the tablet', 'no problem', 'Network issues',
#        'Network problems', 'Breaking of network', 'there is no problem',
#        "i didn't see any problem", 'No challenge', 'No challenges',
#        'no challenge', 'Struggling in using the tablet',
#        'I didn’t face any challenges', 'I don’t see any problem',
#        'Poor network', 'Struggling to type', 'More tablet',
#        'It was very easy to use', 'Lack of internet', 'Network',
#        'Inadequate tablets', 'the network was not stable',
#        'The network problem',
#        'We do not have enough tablets so we have to pair with ourselves',
#        'NO', 'The tablets were not many',
#        "The internet was having an error and we didn't have more tablets",
#        'Not enough tablets', 'The tablets were not enough', 'Net work',
#        'The internet was slow and there was not enough tablets',
#        'Difficulty to use with tablet when there’s no help',
#        'Not enough tablet', 'COUNTING TO RESTART THE TABLETS', 'TYPING',
#        'Not enough', 'Little difficult in operating the table', 'No',
#        'Network problem', 'Network instability', 'Poor access',
#        'Poor internet', 'Internet connection',
#        'inadequate provision of tablet', 'Internet problem',
#        'Connecting with the network', 'Insufficient tablets',
#        'INTERNET CONNECTIVITY', 'internet issues', 'The time was limited',
#        'Power cut',
#        'I was unable to operate the tablet from the beginning',
#        'The timing is too short', 'Inability to manipulate the tablet',
#        'Using the url', 'internet', 'Time allocation',
#        'Password accessing', 'How to use the  Internet',
#        'How to power the tablet', 'Time allocation is too short',
#        'Light went off', 'Nothing', 'NO CHALLENGE',
#        'No challenge encountered', 'Inability to operate the tablet',
#        'Word browser', 'How to access the internet', 'Typing challenges',
#        'Typing challenges and how to use the kids corner', 'NONE',
#        'Operating challenges', 'Light off', 'No challenges encountered',
#        'The challenges was about the network',
#        'How to use the Web browser',
#        'Typing challenges and operating challenges',
#        'I get some understanding for it', 'How to browse',
#        'NOT ENOUGH TIME', 'Using the Web browser',
#        'Power outage prevented us from using the smart board',
#        'Poor internet connectivity', 'The trainer was talking very fast',
#        'NOT ENOUGH DEVICE', 'The tablets are not enough for us',
#        'HOW TO FOCUS ON LESSON', 'No Challenges',
#        'If i go home I will learn how to learn it and teach my sister and friends',
#        'I was okay', 'The network  was unstable',
#        'How to connect the WiFi', 'Lack of Internet on my phone',
#        'No challang', 'My phone was slow',
#        'The challenges I encountered while using technology during the training is the good way of training and using your skills',
#        'The time duration was not sufficient', 'POOR INTERNET CONNECTION',
#        'Poor Internet connection', 'Better', 'No worries or problems',
#        'Non', 'The internet was not stable',
#        'How to swipe something off if you dont need it by switching to the left',
#        'Excellent', 'Very poor', 'Network connection problem',
#        'There was a black out/ power outage',
#        'Identifying the words on the keyboard', 'I had no challenges',
#        'i did not encounter any challenge',
#        'Little or no access to the internet', 'network problems',
#        'excellent', 'no challenges', 'Power off',
#        'They were not any really challenges', 'I feel comfortable',
#        'everything', 'Power outages', 'i  did not  encounter  challenges',
#        'Many challenges', 'typing', 'Typing',
#        'How to engage in coding class',
#        'The network connect was on stable', 'The network connection',
#        'INTERNET ACCESS', 'Poor internet connection',
#        'I had no challenge', 'l did not encounter any Challenges',
#        'I was not able to connect to the internet.', 'none',
#        'No encounter', 'nothing',
#        'Not about to use the internet connection', 'The network',
#        'WiFi connection problem', 'Some of them where really hard',
#        'No challenging', 'poor internet connection', 'NOTHING',
#        'Low access to Internet', 'I were able to connect to the internet',
#        'The network was unstable', 'The internet',
#        'The network was very stable',
#        'Digital footprint in my every day life', 'No encountered',
#        'bad network', 'Cyber crime', 'Comfortable',
#        "i don't have a tablet", 'BAD NETWORK', 'few devices',
#        'I did not face any challenge', 'access to the internet',
#        'speed enough', 'science', 'COMFORTABLE', 'Poor  Network', 'not',
#        'there was no problem', 'No change',
#        'I didnt encounter any challenges', 'doing mistakes', 'good',
#        'no  challenge', 'on', 'How to use the hund held computer',
#        'The time was not enough to use the Tablet',
#        'The time was not enough',
#        'How to access the internet using Wi-Fi',
#        'The time was not enough for our training',
#        'The Tablet device was not enough for us to practice with',
#        'Using the Tablet touch keys for typing',
#        "I didn't encounter any challenge", 'The Internet',
#        'Not enough devices', 'Using to the touch key pads for typing',
#        'Cyber groomers', "The Tablet devices wasn't enough",
#        'Typing using the touch keys',
#        'Using the touchscreen keys was a bit challenging',
#        'The Tablet were few', 'Using phone to access Internet',
#        'Using the laptop to browse', 'Protecting my data from fruad',
#        'How to on the tablet', 'Restarting the tablet',
#        'Using the phone to browse', 'How to connect to the Internet',
#        'How to download the apps', 'How to use the tablet',
#        'How to install the apps', 'How to on and off the tablet',
#        'How to use the apps', 'Using the apps on the tablet',
#        'Using the install apps', 'the challenges was about the network',
#        'there was poor network', 'I want one tablet for myself',
#        'I want one tablet to learn', 'Search of maths kids',
#        'I wanted one tablet for my side',
#        'I like everything about the training', 'Not', 'Game',
#        'I want one tablet', 'I want one for myself',
#        'I want one of the tablets', 'no', 'Browsing', 'Using the tablet',
#        'Closing app using tablet', 'Connecting to the Internet',
#        'Had issues with the introduction', 'On and off the tablet',
#        'Using the stem apps', 'Browsing with the tablet',
#        'Alot of challenges', 'Turning on and off the tablet',
#        'Using the touch keys', 'Connecting to the network', 'no network',
#        'no internet', 'not much time to practice more',
#        'our light went off most times', 'out light keeps going off',
#        'I feel proud and happy', 'I feel very happy', 'no thing',
#        'Search for information', 'How to On and off', 'TECHNOLOGY',
#        'Learning challenging', 'no challeng', 'Selecting apps',
#        'I did not face any challenges', 'Eye problem',
#        'My challenges were how to connect to the internet',
#        'The challenges is that whilst the are teaching some do not understood',
#        'very easy', 'about cyber security', 'typing aspects',
#        'No challengs',
#        'I have learn the online studies and how to search for information on internet',
#        'To conect to the intanet', 'Reading challenged.',
#        'Learning more  good encounters', 'No challengers',
#        'It is very good',
#        'Because it was my first time, it was very challenging',
#        'checking danceing', 'No  challenges', 'No challenenges',
#        'the typing', 'No challeng', 'Light Out', 'our light went off',
#        'we were not able to use the device for more practice just that internet provision was late',
#        'light out plenty', 'light', 'less time to practice', 'LIGHT OUT',
#        'light out more times', 'less time', 'Less time',
#        'light out always', 'low battery', 'more time to learn',
#        'less time to learn', "And I can't use it", 'Very expensive',
#        'How to how to connect the Wi-Fi',
#        'We learnt application on internet', 'Less access to wifi',
#        'Internet connection problem', 'Data', 'It good',
#        'It was easy In learn with the IPads',
#        'My sitting partener was not allowing me to engage in using the tablets',
#        'It was somehow boring', 'Typing fast',
#        'Learners were making noises', 'They were distracting others',
#        'Network not being available', 'Misunderstanding',
#        'They were using the phone to play music 🎵🎶',
#        "I didn't face any challenges", 'Making noises',
#        'light out and no internet', 'Good',
#        "I didn't know how to access internet", 'Actually none',
#        'Confident', 'To access with the internet',
#        'Three people sharing one Devi', 'How to connect usong the wifi',
#        'How they describe the internet', 'The best', 'Easier',
#        'How to go to specific gaming link', 'Searching for game link',
#        'Researching on links', 'Some how', 'Researching the game apps',
#        'Data connection', 'Know challenges', 'Was the network',
#        'Mathematics', 'It was okay', 'I  feel  okay', 'Data problem',
#        'Sharing with another person', 'Watching directly into gadget',
#        'No internet connection', 'I DONT HAVE A PHONE TO USE FOR MYSELF',
#        'No internet', 'Please no challenge',
#        "When I connect to the WiFi, I didn't ask for assistance",
#        'I had difficulty connecting to the ibox', 'Search',
#        'Network quality', 'TYPING MISTAKE',
#        'There was light out and we were not able to practice all of it',
#        'I do not have any problem', 'There was light out', 'No Challenge',
#        'The network were unstable', 'NOT BEING ABLE TO APPLY WHAT LEARNT',
#        'Searching  on search engines', 'Lights out',
#        "There was no light and internet wasn't available",
#        'There was lights out', 'There was no internet',
#        'No challenge at the moment', 'No difficulty',
#        'Tapping different icons', 'Internet connectivity issues',
#        'WIFI CONNECTION PROBLEM .', 'WIFI CONNECTION PROBLEM',
#        'Put lock on your phone', 'WIFI PASSWORD ENTRY WAS DIFFICULT.',
#        'My friends did not allow me  to use the tablet.',
#        'Network challenges', 'Difficulty in navigating', 'No network',
#        'Installing of application', 'How to connect to the internet',
#        'Poor connection', 'Poor Internet',
#        'How to get access to internet', 'Unstable internet',
#        'Internet challenges', 'when searching for an information.',
#        'Unstable internet connection', 'how to secure my strong password',
#        'No problem', '3 pupils have to pair a tablet', 'WIFI CONNECTION.',
#        'just a few tablets', 'No Internet', 'network problem',
#        'WIFI CONNECTION', 'Internet availability',
#        'Not access to Internet connection',
#        'How to connect the Wi-Fi and how to search using the url',
#        'Shortage of data', 'The tablets where not enough',
#        'internet challenge', 'Not enough tablets to us to use',
#        'Lack of Internet connection at some point',
#        'Turning on the tablet', 'Wifi Connection',
#        'Shortage of data at some point in the presentation',
#        'INTERNET PROBLEM', 'NO PROBLEM', 'On the tablet', 'All was good',
#        'First time', 'Network connectivity.', 'Network challenge',
#        'The tapping and the headset', 'small chanllenge',
#        'Because of unfamiliarity with it I was struggling', 'Yes',
#        'The internet connection was poor.',
#        'Unfamiliarity with the device due to lack of access',
#        "The tablet' volume was not stable.", 'how to type a search',
#        'Network connection.', 'The internet was slow',
#        'Typing was very difficult on the tablet',
#        'Scrolling with Accessibility was a bit tedious',
#        'Using the keyboard is a little bit difficult',
#        'Internet Connection', 'the tablet is slow',
#        'Using accessibility to connect to internet',
#        'Typing was very difficult', 'Unfamiliarity with the device',
#        'Connecting to the WiFi was a problem for me',
#        'When locating the browser', 'The internet connection',
#        'Typing into the search engine was a challenge',
#        'School tablets (not from huawei )were very slow and difficult to use',
#        'Cybercrime', 'N/a', 'Internet challenge',
#        'It was my first time using the tablet.',
#        'Was difficult navigating through the tablet',
#        'Accessing the Internet was a problem', 'Typing was a challenge',
#        'Turning on and off and searching for information',
#        'Small challenge',
#        'Difficulty in operating the tablet because my first time',
#        'Short training duration', 'Unfamiliarity', 'Internet  challenge',
#        'The internet was off at a point', 'Internet off at some point',
#        'Internet off at a point', 'Internet was off at some point',
#        'Navigating', 'Typing on the tablet', 'Searching on the tablet',
#        'Navigating search Engines', 'Meaning of STEM', 'browsers',
#        'Poor Internet connectivity',
#        'Poor Internet connectivity and inadequate ICT tools',
#        'Poor Internet connectivity al',
#        'Poor Internet connectivity and inadequate ICT tools for learning',
#        'Limited tablet', 'Difficulty in navigating tge tablet',
#        'Typing to search', 'There is Internet', 'No WiFi', 'How to type',
#        'I could not hear some of the things on the tablet',
#        'How to type using tablet',
#        'I could not hear some of words on the tablet',
#        'It is difficult to operate the tablet',
#        'The Internet was not good',
#        'I wasn’t able to access some features',
#        'Sometimes the talk back goes off',
#        'I could not access some features on the tablet',
#        'Noticing the mobile application', 'No music',
#        'I couldn’t not hear well', 'I was not hearing the tablet',
#        'Lack of Internet', 'Inadequate devices', 'Lack  of  data',
#        'Poor  internet  connection', 'How to get the device',
#        'I felt better', 'not bad challenges',
#        'Inadequate devices for training.', 'Lack of data',
#        'Creating a password for myself',
#        'Creating a password for my self', 'Getting a phone',
#        'Inadequate device', 'Devices not enough', 'Limited devices',
#        'Bad', 'Cyberbulling', 'non', 'I was fine',
#        'The boy and the old man', "No didn't", 'Choosing an application',
#        'I was not hearing the sound from the tablet',
#        'Navigating the tablet', 'I could not hear some of the things',
#        'The headphones will not loud', 'Using the buttons',
#        'Using the buttons on the laptop', 'I could not hear clearly',
#        'Navigating the some of the applications',
#        'My challenge was on turning on the tablet but after we were taught how to, now I can turning it on and off by holding the power button for 5 seconds',
#        'More learning skills'], dtype=object)

# %%
df.columns
# Out:
# Index(['start_time', 'end_time', '1. Name ', 'age', 'gender', 'name_of_school',
#        'grade_or_class', 'region_of_school',
#        'how_would_you_rate_the_overall_training_experience?',
#        'what_aspects_of_the_training_did_you_enjoy_most?',
#        'were_the_training_objectives_clearly_communicated?',
#        'how_engaging_did_you_find_the_training_sessions?',
#        'how_effective_were_the_trainers_in_delivering_the_content?',
#        'how_would_you_rate_the_training_materials_provided?',
#        'what_new_skills_or_knowledge_did_you_acquire_from_the_training?',
#        'how_confident_do_you_feel_in_using_technology_for_learning_after_the_training?',
#        'what_challenges_did_you_encounter_while_using_technology_during_the_training?',
#        'how_do_you_plan_to_apply_what_you_learned_in_your_studies?',
#        'what_topics_would_you_like_to_see_covered_in_future_training_sessions?',
#        'do_you_have_any_suggestions_to_improve_the_training_program?',
#        'any_additional_comments_or_feedback?'],
#       dtype='object')

# %%
future_topics = df["what_topics_would_you_like_to_see_covered_in_future_training_sessions?"].value_counts()

# Join all responses into a single string
text = " ".join(future_topics.index) 

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, random_state=42).generate(text)

# Plot the word cloud
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title("Topics likely to see covered in future training sessions")
plt.axis("off")
plt.savefig("topics.png")
plt.show()
