# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import openpyxl

# %%
df = pd.read_excel('Book1.xlsx', engine='openpyxl')
df.head()
# Out:
#                 Name Age  Gender     Contact  \
# 0  Emmanuellla Tofah  45  Female  0246268839
# 1     Roselyn Lartey  14  Female         NaN
# 2      Grace Quainoo  14  Female  0245759767
# 3  Beatrice Attramah  14  Female  0548509101
# 4   Benedicta Mensah  14  Female         NaN
#
#                       Name of School Current Grade Level Region of School  \
# 0          No.1 Basic School, Akatsi               JHS 1            Volta
# 1  Enchi Roman Catholic Basic School               JHS 3          Western
# 2  Enchi Roman Catholic Basic School               JHS 2          Western
# 3                     Roman Catholic               JHS 3          Western
# 4               Enchi Roman Catholic               JHS 2          Western
#
#   Do you have access to a device for online Learning?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   If yes, what type of device do you use?  \
# 0                                  Laptop
# 1                              Smartphone
# 2                                     NaN
# 3                              Smartphone
# 4                                     NaN
#
#   How comfortable are you with using digital devices for Learning?  ...  \
# 0                                           Moderate                ...
# 1                                        Comfortable                ...
# 2                                           Moderate                ...
# 3                                   Very Comfortable                ...
# 4                                           Moderate                ...
#
#   What is your preferred learning style?  \
# 0              Visual (videos, diagrams)
# 1       Auditory (lectures, discussions)
# 2              Visual (videos, diagrams)
# 3              Visual (videos, diagrams)
# 4              Visual (videos, diagrams)
#
#   Have you used an online learning platform before? If yes, please specify  \
# 0                                                No                    NaN
# 1                                                No                    NaN
# 2                                                No                    NaN
# 3                                                No                    NaN
# 4                                                No                    NaN
#
#   What is your level of experience with online/remote learning platforms?  \
# 0                                    Some experience
# 1                                      No experience
# 2                                      No experience
# 3                                      No experience
# 4                                      No experience
#
#   What are the main challenges you have faced (or expect to face) with online learning?  \
# 0        Lack of access to reliable internet/devices
# 1           Difficulty staying engaged and motivated
# 2   Balancing schoolwork with other responsibilities
# 3        Lack of access to reliable internet/devices
# 4   Balancing schoolwork with other responsibilities
#
#   If others, please specify  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#   What kind of support would you find most helpful in transitioning to technology-enabled learning?  \
# 0   Training on how to use online learning platforms
# 1   Training on how to use online learning platforms
# 2   Training on how to use online learning platforms
# 3   Training on how to use online learning platforms
# 4  Opportunities for virtual peer collaboration a...
#
#   Have you heard about the TeOSS project before?  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   If yes, what do you know about the TeOSS project?  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   What are your expectations for the TeOSS Learners Training Program?
# 0  It will enable me use online learning platform...
# 1             To help learning through digital means
# 2                     To acquire knowledge about ICT
# 3                    More online learning experience
# 4                     To acquire knowledge about ICT
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (656, 24)

# %%
st.write(df.columns)
# Out:
# Index(['Name', 'Age', 'Gender', 'Contact', 'Name of School',
#        'Current Grade Level', 'Region of School',
#        'Do you have access to a device for online Learning?',
#        'If yes, what type of device do you use?',
#        'How comfortable are you with using digital devices for Learning?',
#        'Do you have internet access?',
#        ' If yes, what type of internet access do you use?', 'Others specify',
#        'How comfortable are you using the internet to access information?',
#        'What is your preferred learning style?',
#        'Have you used an online learning platform before?',
#        'If yes, please specify',
#        'What is your level of experience with online/remote learning platforms?',
#        'What are the main challenges you have faced (or expect to face) with online learning?',
#        'If others, please specify',
#        'What kind of support would you find most helpful in transitioning to technology-enabled learning?',
#        'Have you heard about the TeOSS project before?',
#        'If yes, what do you know about the TeOSS project?',
#        'What are your expectations for the TeOSS Learners Training Program?'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                                                                                                 object
# Age                                                                                                   int64
# Gender                                                                                               object
# Contact                                                                                              object
# Name of School                                                                                       object
# Current Grade Level                                                                                  object
# Region of School                                                                                     object
# Do you have access to a device for online Learning?                                                  object
# If yes, what type of device do you use?                                                              object
# How comfortable are you with using digital devices for Learning?                                     object
# Do you have internet access?                                                                         object
#  If yes, what type of internet access do you use?                                                    object
# Others specify                                                                                       object
# How comfortable are you using the internet to access information?                                    object
# What is your preferred learning style?                                                               object
# Have you used an online learning platform before?                                                    object
# If yes, please specify                                                                               object
# What is your level of experience with online/remote learning platforms?                              object
# What are the main challenges you have faced (or expect to face) with online learning?                object
# If others, please specify                                                                            object
# What kind of support would you find most helpful in transitioning to technology-enabled learning?    object
# Have you heard about the TeOSS project before?                                                       object
# If yes, what do you know about the TeOSS project?                                                    object
# What are your expectations for the TeOSS Learners Training Program?                                  object
# dtype: object

# %%
df.describe()
# Out:
#                               Name  Age Gender     Contact  \
# count                          663  663    663         466
# unique                         625   25      2         427
# top     Joseph Walter Eduam Donkor   14   Male  0204818822
# freq                             3  148    359           5
#
#               Name of School Current Grade Level Region of School  \
# count                    663                 663              663
# unique                   170                   9                8
# top     Elmina Methodist JHS               JHS 3          Central
# freq                     109                 197              278
#
#        Do you have access to a device for online Learning?  \
# count                                                 663
# unique                                                  2
# top                                                   Yes
# freq                                                  535
#
#        If yes, what type of device do you use?  \
# count                                      531
# unique                                       4
# top                                 Smartphone
# freq                                       390
#
#        How comfortable are you with using digital devices for Learning?  ...  \
# count                                                 663                ...
# unique                                                  4                ...
# top                                      Very Comfortable                ...
# freq                                                  279                ...
#
#        What is your preferred learning style?  \
# count                                     663
# unique                                      3
# top                 Visual (videos, diagrams)
# freq                                      397
#
#        Have you used an online learning platform before?  \
# count                                                663
# unique                                                 2
# top                                                   No
# freq                                                 434
#
#        If yes, please specify  \
# count                     179
# unique                    100
# top                    Google
# freq                       33
#
#        What is your level of experience with online/remote learning platforms?  \
# count                                                 663
# unique                                                  3
# top                                       Some experience
# freq                                                  348
#
#        What are the main challenges you have faced (or expect to face) with online learning?  \
# count                                                 663
# unique                                                  6
# top           Lack of access to reliable internet/devices
# freq                                                  401
#
#        If others, please specify  \
# count                         12
# unique                        11
# top                   Not really
# freq                           2
#
#        What kind of support would you find most helpful in transitioning to technology-enabled learning?  \
# count                                                 663
# unique                                                  6
# top      Training on how to use online learning platforms
# freq                                                  522
#
#        Have you heard about the TeOSS project before?  \
# count                                             663
# unique                                              2
# top                                                No
# freq                                              508
#
#        If yes, what do you know about the TeOSS project?  \
# count                                                151
# unique                                               114
# top                        Providing learning technology
# freq                                                   8
#
#        What are your expectations for the TeOSS Learners Training Program?
# count                                                 663
# unique                                                452
# top                                                 Learn
# freq                                                   37
#
# [4 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 24 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Name                                                                                               663 non-null    object
#  1   Age                                                                                                663 non-null    object
#  2   Gender                                                                                             663 non-null    object
#  3   Contact                                                                                            466 non-null    object
#  4   Name of School                                                                                     663 non-null    object
#  5   Current Grade Level                                                                                663 non-null    object
#  6   Region of School                                                                                   663 non-null    object
#  7   Do you have access to a device for online Learning?                                                663 non-null    object
#  8   If yes, what type of device do you use?                                                            531 non-null    object
#  9   How comfortable are you with using digital devices for Learning?                                   663 non-null    object
#  10  Do you have internet access?                                                                       663 non-null    object
#  11   If yes, what type of internet access do you use?                                                  663 non-null    object
#  12  Others specify                                                                                     3 non-null      object
#  13  How comfortable are you using the internet to access information?                                  663 non-null    object
#  14  What is your preferred learning style?                                                             663 non-null    object
#  15  Have you used an online learning platform before?                                                  663 non-null    object
#  16  If yes, please specify                                                                             179 non-null    object
#  17  What is your level of experience with online/remote learning platforms?                            663 non-null    object
#  18  What are the main challenges you have faced (or expect to face) with online learning?              663 non-null    object
#  19  If others, please specify                                                                          12 non-null     object
#  20  What kind of support would you find most helpful in transitioning to technology-enabled learning?  663 non-null    object
#  21  Have you heard about the TeOSS project before?                                                     663 non-null    object
#  22  If yes, what do you know about the TeOSS project?                                                  151 non-null    object
#  23  What are your expectations for the TeOSS Learners Training Program?                                663 non-null    object
# dtypes: object(24)
# memory usage: 124.4+ KB

# %%
df = df[pd.to_numeric(df['Age'], errors='coerce').notnull()]

# %%
df["Age"] = df["Age"].astype(int)
# Out:
# C:\Users\Marc Bright\AppData\Local\Temp\ipykernel_15656\3729672396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 656 entries, 0 to 662
# Data columns (total 24 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Name                                                                                               656 non-null    object
#  1   Age                                                                                                656 non-null    int64
#  2   Gender                                                                                             656 non-null    object
#  3   Contact                                                                                            461 non-null    object
#  4   Name of School                                                                                     656 non-null    object
#  5   Current Grade Level                                                                                656 non-null    object
#  6   Region of School                                                                                   656 non-null    object
#  7   Do you have access to a device for online Learning?                                                656 non-null    object
#  8   If yes, what type of device do you use?                                                            525 non-null    object
#  9   How comfortable are you with using digital devices for Learning?                                   656 non-null    object
#  10  Do you have internet access?                                                                       656 non-null    object
#  11   If yes, what type of internet access do you use?                                                  656 non-null    object
#  12  Others specify                                                                                     3 non-null      object
#  13  How comfortable are you using the internet to access information?                                  656 non-null    object
#  14  What is your preferred learning style?                                                             656 non-null    object
#  15  Have you used an online learning platform before?                                                  656 non-null    object
#  16  If yes, please specify                                                                             177 non-null    object
#  17  What is your level of experience with online/remote learning platforms?                            656 non-null    object
#  18  What are the main challenges you have faced (or expect to face) with online learning?              656 non-null    object
#  19  If others, please specify                                                                          12 non-null     object
#  20  What kind of support would you find most helpful in transitioning to technology-enabled learning?  656 non-null    object
#  21  Have you heard about the TeOSS project before?                                                     656 non-null    object
#  22  If yes, what do you know about the TeOSS project?                                                  149 non-null    object
#  23  What are your expectations for the TeOSS Learners Training Program?                                656 non-null    object
# dtypes: int64(1), object(23)
# memory usage: 128.1+ KB

# %%
df.isna().sum()
# Out:
# Name                                                                                                   0
# Age                                                                                                    0
# Gender                                                                                                 0
# Contact                                                                                              195
# Name of School                                                                                         0
# Current Grade Level                                                                                    0
# Region of School                                                                                       0
# Do you have access to a device for online Learning?                                                    0
# If yes, what type of device do you use?                                                              131
# How comfortable are you with using digital devices for Learning?                                       0
# Do you have internet access?                                                                           0
#  If yes, what type of internet access do you use?                                                      0
# Others specify                                                                                       653
# How comfortable are you using the internet to access information?                                      0
# What is your preferred learning style?                                                                 0
# Have you used an online learning platform before?                                                      0
# If yes, please specify                                                                               479
# What is your level of experience with online/remote learning platforms?                                0
# What are the main challenges you have faced (or expect to face) with online learning?                  0
# If others, please specify                                                                            644
# What kind of support would you find most helpful in transitioning to technology-enabled learning?      0
# Have you heard about the TeOSS project before?                                                         0
# If yes, what do you know about the TeOSS project?                                                    507
# What are your expectations for the TeOSS Learners Training Program?                                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df["Age"].value_counts()
# Out:
# Age
# 14    148
# 13    138
# 12     93
# 11     70
# 15     66
# 10     33
# 9      27
# 8      25
# 16     24
# 17     10
# 18      5
# 7       5
# 19      3
# 6       3
# 20      2
# 21      2
# 45      1
# 26      1
# Name: count, dtype: int64

# %%
age_counts = df["Age"].value_counts()

# %%
# Print the gender counts
print("Gender Distribution:")
print(age_counts)
# Out:
# Gender Distribution:
# Age
# 14    148
# 13    138
# 12     93
# 11     70
# 15     66
# 10     33
# 9      27
# 8      25
# 16     24
# 17     10
# 18      5
# 7       5
# 19      3
# 6       3
# 20      2
# 21      2
# 45      1
# 26      1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,7))
sns.barplot(data = gender_counts)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      357
# Female    299
# Name: count, dtype: int64

# %%
gender_counts = df["Gender"].value_counts()

# %%
# Print the gender counts
print("Gender Distribution:")
print(gender_counts)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data = gender_counts)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.savefig('age_dis.png')
plt.show()
# Out:
# Gender Distribution:
# Gender
# Male      357
# Female    299
# Name: count, dtype: int64

# %%
region_counts = df["Region of School"]

# %%
plt.figure(figsize = (12,7))
sns.barplot(data = region_counts)
plt.title("Region Distribution")
plt.savefig('region_dis.png')
plt.show()

# %%
device_use_online = df["If yes, what type of device do you use?"]

# %%
plt.figure(figsize = (15,6))
sns.histplot(data = device_use_online)
plt.title("Devices used for Online studies")
plt.show()

# %%
support_needs = df["What kind of support would you find most helpful in transitioning to technology-enabled learning?"].value_counts()
print(support_needs)
# Out:
# What kind of support would you find most helpful in transitioning to technology-enabled learning?
# Training on how to use online learning platforms                       516
# Opportunities for virtual peer collaboration and social interaction     63
# Tips for staying engaged and motivated in remote settings               28
# Guidance on time management and balancing responsibilities              25
# Access to technical support and troubleshooting                         20
# Others                                                                   4
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,9))
sns.barplot(data = support_needs)
plt.title("Support Needs for Technology-Enabled Learning")
plt.xlabel("Support Type")
plt.ylabel("Count")

plt.xticks(rotation=-80)

plt.show()

# %%
df["What is your preferred learning style?"].unique()
# Out:
# array(['Visual (videos, diagrams)', 'Auditory (lectures, discussions)',
#        'Kinesthetic (hands-on activities)'], dtype=object)

# %%
df_filtered = df[df['Have you used an online learning platform before?'] == 'Yes']


df_male = df_filtered[df_filtered['Gender'] == 'Male']
df_female = df_filtered[df_filtered['Gender'] == 'Female']


plt.figure(figsize=(12, 6))
sns.histplot(df_male['What is your preferred learning style?'], bins=20, alpha=0.7, label='Male')
sns.histplot(df_female['What is your preferred learning style?'], bins=20, alpha=0.7, label='Female')

plt.title("Preferred Learning Styles by Gender")
plt.xlabel("Preferred Learning Style")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
df["Have you heard about the TeOSS project before?"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
teoss_awareness = df["Have you heard about the TeOSS project before?"]
print(teoss_awareness.value_counts())

plt.figure(figsize = (12,6))
sns.barplot(data = teoss_awareness)
plt.title("TeOSS Awareness")
plt.xlabel("Count")
plt.ylabel("Have you heard about the TeOSS project before?")
plt.show()
# Out:
# Have you heard about the TeOSS project before?
# No     503
# Yes    153
# Name: count, dtype: int64
